# %% [markdown]
# Abstraction
#
# Unnecessary details hide karna aur sirf important cheezen show karna = Abstraction
# Python mein abstraction ke liye hum usually Abstract Class aur Abstract Method use karte hain
# Abstract Class ka direct object nahi banta; child class abstract methods ko implement karke object bana sakti hai.

# %%
from abc import ABC, abstractmethod
class Vehicle(ABC):

    @abstractmethod
    def move(self):
        pass


class Car(Vehicle):

    def move(self):
        print("Car is moving")


car = Car()
car.move()
# Out:
# Car is moving

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass

# %%
from abc import ABC, abstractmethod

class Payment(ABC):

    @abstractmethod
    def pay(self, amount):
        pass


class JazzCash(Payment):

    def pay(self, amount):
        print(f"Paid {amount} through JazzCash")


class Bank(Payment):

    def pay(self, amount):
        print(f"Paid {amount} through Bank")
        jazzcash = JazzCash()
bank = Bank()

# jazzcash.pay(500)
# bank.pay(1000)
# Payment → Abstract Class
# pay() → Abstract Method
# JazzCash → Payment se inherit kar raha hai
# Bank → Payment se inherit kar raha hai
# # Dono classes apne tareeqe se pay() implement kar rahi hain..

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


class Circle(Shape):

    def area(self):
        print("Circle area")


circle = Circle()
circle.area()
# Out:
# Circle area
