# %% [markdown]
# Polymorphism
#
# Polymorphism ka simple matlab:Same method name, different classes, different behavior.

# %%
class Dog:
    def sound(self):
        print("Dog barks")


class Cat:
    def sound(self):
        print("Cat meows")


dog = Dog()
cat = Cat()

dog.sound()
cat.sound()
# Out:
# Dog barks
# Cat meows

# %%
class Car:
    def move(self):
        print("Car is moving")


class Bike:
    def move(self):
        print("Bike  is Moving")


car1= Car()
bike1 = Bike()

car1.move()
bike1.move()
# Out:
# Car is moving
# Bike  is Moving

# %%
class Cat:
    def sound(self):
        print("Cat meows")


class Dog:
    def sound(self):
        print("Dog is bark")


animals = [Cat(), Dog()]

for animal in animals:
    animal.sound()
# Out:
# Cat meows
# Dog is bark

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")


class Dog(Animal):
    def sound(self):
        print("Dog barks")


class Cat(Animal):
    def sound(self):
        print("Cat meows")


animals = [Dog(), Cat()]

for animal in animals:
    animal.sound()
# Out:
# Dog barks
# Cat meows

# %%
class Vehicle:
    def move(self):
        print("Vehicle is moving")


class Car(Vehicle):
    def move(self):
        print("Car is driving")


class Bike(Car):
    def move(self):
        print("Bike is riding")


Vehicles = [Car(), Bike()]

for vehicle in vehicles:
    vehicle.move()
# Out:
# Car is moving
# Bike is moving

# %%
class Shape:
    def area(self):
        print("Shape is directionless")


class Circle(Shape):
    def area(self):
        print("Circle area")


class Rectangle(Circle):
    def area(self):
        print("Rectangle area")


Shapes = [Circle(), Rectangle()]

for Shape in Shapes:
    Shape.area()
# Out:
# Circle area
# Rectangle area
